# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from pandas import Series,DataFrame

url = 'https://www.nirfindia.org/2023/ManagementRanking.html'


result = requests.get(url)
c = result.content

soup = BeautifulSoup(c, 'html.parser')

table = soup.find('table',{'class':'table table-condensed dataTable no-footer dtr-inline'})
table = soup.find_all('table')[0]
df=pd.read_html(str(table))[0]
df
# Out:
#     Institute ID                                               Name  \
# 0    IR-M-S-8890  Indian Institute of Management AhmedabadMore D...
# 1    IR-M-S-8903  Indian Institute of Management BangaloreMore D...
# 2    IR-M-S-8909  Indian Institute of Management KozhikodeMore D...
# 3    IR-M-S-8972  Indian Institute of Management CalcuttaMore De...
# 4    IR-M-I-1074  Indian Institute of Technology DelhiMore Detai...
# ..           ...                                                ...
# 95   IR-M-U-0107                        Jamia HamdardMore Details |
# 96  IR-M-S-14553  National Institute of Agricultural Extension M...
# 97  IR-M-S-15911       Indian Institute of ManagementMore Details |
# 98  IR-M-C-32887    New Delhi Institute Of ManagementMore Details |
# 99   IR-M-U-0162  Guru Jambheshwar University of Science and Tec...
#
#          City             State  Score  Rank
# 0   Ahmedabad           Gujarat  83.20     1
# 1   Bengaluru         Karnataka  80.89     2
# ...

# %%
df.to_csv(r'C:\Users\Public\NIRF_RANKING.csv')

# %%
# for running this code user must have pandas profiling library 
# !pip install ydata-profiling


import pandas as pd
from pandas_profiling import ProfileReport

# Read the CSV file into a DataFrame
df = pd.read_csv('NIRF_RANKING.csv')

# Generate a profile report
profile = ProfileReport(df)

# Save the profile report as an HTML file
profile.to_file(output_file="NIRF.html")
# Out:
# C:\Users\Akanksha Sharma\anaconda3\Lib\site-packages\numba\core\decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# C:\Users\Akanksha Sharma\anaconda3\Lib\site-packages\visions\backends\shared\nan_handling.py:50: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @nb.jit
# ...

# %% [markdown]
# ### The link to access the panda profiling report: https://raw.githack.com/akanksha1711/my_repo.github.io/main/NIRF%20(Panda%20Profiling%20Report).html

# %% [markdown]
# # Here are some of the Snapshots from the HTML file

# %% [markdown]
# ![Screenshot%202023-09-09%20235147.png](attachment:Screenshot%202023-09-09%20235147.png)

# %% [markdown]
# ![Screenshot%202023-09-09%20235120.png](attachment:Screenshot%202023-09-09%20235120.png)

# %% [markdown]
# ![Screenshot%202023-09-09%20235207.png](attachment:Screenshot%202023-09-09%20235207.png)

# %% [markdown]
# ![Screenshot%202023-09-09%20235441.png](attachment:Screenshot%202023-09-09%20235441.png)

# %% [markdown]
# ![Screenshot%202023-09-09%20235517.png](attachment:Screenshot%202023-09-09%20235517.png)

# %% [markdown]
# ![Screenshot%202023-09-09%20235646.png](attachment:Screenshot%202023-09-09%20235646.png)

# %% [markdown]
# ![WhatsApp%20Image%202023-09-10%20at%201.jpeg](attachment:WhatsApp%20Image%202023-09-10%20at%201.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-09-10%20at%201%20%281%29.jpeg](attachment:WhatsApp%20Image%202023-09-10%20at%201%20%281%29.jpeg)

# %% [markdown]
# ![Screenshot%202023-09-10%20014302.png](attachment:Screenshot%202023-09-10%20014302.png)

# %% [markdown]
# ![Screenshot%202023-09-10%20014343.png](attachment:Screenshot%202023-09-10%20014343.png)
